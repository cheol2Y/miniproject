# %%
#!pip install -U finance-datareader

# %%
#!pip install schedule

# %%
import matplotlib.pyplot as plt
import FinanceDataReader as fdr
import pandas as pd

# %%
df_krx = fdr.StockListing('KRX')

# %%
df_krx[:5]

# %%
data1 = dict(zip(df_krx['Name'], df_krx['Close']))

# %%
type(data1)
# Out:
# dict

# %%
plt.bar(df_krx[:5]['Name'], df_krx[:5]['Close'])
# Out:
# <BarContainer object of 5 artists>

# %%
#plt1.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plt1.show()
#
# AttributeError: 'BarContainer' object has no attribute 'show'

# %%
#plt1
#뭔가 껄끄럽긴 하지만 일단 이미지 파일로 저장할 수 있는 상황까지 만든 거겠지? png로
# Out:
# <BarContainer object of 5 artists>

# %%
#schedule.every().hour.do(fetch_stock_data)

#while True:
    #schedule.run_pending()
    #time.sleep(30)
# Out:
# 반복됨
# 반복됨
# 반복됨
# 반복됨
# 반복됨
# 반복됨
# 반복됨
# 반복됨
# 반복됨
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from flask import Flask, jsonify

# %%
#app = Flask(__name__)

# %%
data1
# Out:
# {'삼성전자': '73300',
#  'SK하이닉스': '139300',
#  'LG에너지솔루션': '423000',
#  '삼성바이오로직스': '702000',
#  '삼성전자우': '59500',
#  '현대차': '191700',
#  'POSCO홀딩스': '478500',
#  'NAVER': '225500',
#  '기아': '89200',
#  'LG화학': '490500',
#  '에코프로비엠': '320000',
#  '삼성SDI': '450500',
#  '포스코퓨처엠': '359500',
#  '셀트리온': '171600',
#  '카카오': '54900',
#  '삼성물산': '128700',
#  'KB금융': '53100',
#  '현대모비스': '224000',
#  '신한지주': '38550',
#  '에코프로': '643000',
#  'LG전자': '96800',
#  '삼성생명': '70600',
#  'SK이노베이션': '138500',
#  'LG': '86600',
#  'SK': '177500',
#  '카카오뱅크': '27050',
#  '삼성에스디에스': '164800',
#  '하나금융지주': '42950',
#  '셀트리온헬스케어': '76100',
#  '한국전력': '19390',
#  'KT&G': '91400',
#  '삼성화재': '256000',
#  '메리츠금융지주': '57100',
#  '에코프로머티': '168600',
#  '삼성전기': '154000',
#  'HD현대중공업': '124100',
#  'SK텔레콤': '50100',
#  'HMM': '15860',
#  '고려아연': '499000',
#  '포스코인터내셔널': '58400',
#  '두산에너빌리티': '15860',
#  '크래프톤': '209000',
#  '하이브': '237500',
#  '우리금융지주': '12990',
#  '기업은행': '11880',
#  'KT': '36350',
# ...

# %%
#@app.route('/api/data', methods=['GET'])
#def get_data4():
    #data1
    #return jsonify(data1)

#if __name__ == '__main__':
    #app.run(debug=True)
#data는 json으로 바꿀 수 있는 딕셔너리, 리스트여야 함. 데이터프레임이라면 딕셔너리로 변환한 뒤 jsonify를 해야 한다.
#하 일단 이미지로 넘어가기

# %%
get_data4()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 get_data4(data1)
#
# Cell In[30], line 3, in get_data4(data_in)
#       1 @app.route('/api/data', methods=['GET'])
#       2 def get_data4(data_in):
# ----> 3     return jsonify(data_in)
#
# File c:\dev\웹 개발 프로젝트\fastapi\.venv\Lib\site-packages\flask\json\__init__.py:170, in jsonify(*args, **kwargs)
#     138 def jsonify(*args: t.Any, **kwargs: t.Any) -> Response:
#     139     """Serialize the given arguments as JSON, and return a
#     140     :class:`~flask.Response` object with the ``application/json``
#     141     mimetype. A dict or list returned from a view will be converted to a
#    (...)
#     168     .. versionadded:: 0.2
#     169     """
# --> 170     return current_app.json.response(*args, **kwargs)
#
# ...

# %%
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware

# %%
app = FastAPI()

# %%
origins = [
    "http://localhost",
    "http://localhost:8080",
    "http://localhost:8000"
]

# %%
app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"]
)

# %%
@app.get("/api/index")
def index():
    return data1

# %%
index()
#이렇게 함수를 볼 순 없는듯
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 index()
#       2 #이렇게 함수를 볼 순 없는듯
#
# Cell In[16], line 3, in index()
#       1 @app.get("/api/index")
#       2 def index():
# ----> 3     return jsonify(data1)
#
# NameError: name 'jsonify' is not defined

# %%
#여기부턴 이미지
from flask import render_template
from io import BytesIO
import base64

# %%
app = Flask(__name__)

# %%
img_data = BytesIO()
plt1 = plt.savefig(img_data, format='png')
img_data.seek(0)
img_base64 = base64.b64encode(img_data.read()).decode('utf-8')

img_base64

#지금 진짜 초집중중
# Out:
# '...'

# %%
#img_base64.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 img_base64.show()
#
# AttributeError: 'str' object has no attribute 'show'

# %%
@app.route('/')
def index():
    return render_template('index.html', img_data=generate_plot())
